# %% [markdown]
# <a href="https://colab.research.google.com/github/leesolhahaha/data-analysis-ta/blob/main/3.%20%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%82%B4%ED%8E%B4%EB%B3%B4%EA%B3%A0_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 데이터 입출력

# %% [markdown]
# * 판다스는 <u>다양한 형태의 외부 파일을 읽어와서 데이터프레임으로 변환</u>하는 함수를 제공한다.
# * 어떤 파일이든 판다스 객체인 데이터프레임으로 변환되고 나면 판다스의 모든 함수와 기능을 자유롭게 사용할 수 있다.
# * 반대로 <u>데이터프레임을 다양한 유형의 파일로 저장</u>할 수도 있다.

# %% [markdown]
# * csv파일로 저장하기
#     * **DataFrame객체.to_csv('파일이름(경로)')**
# * csv파일로 읽어오기
#     * **pandas.read_csv('파일이름(경로)', index_col=인덱스컬럼번호, header=헤더로 지정할 행번호, sep='구분자')**

# %%
# 판다스 모듈 임포트

import pandas as pd

# %%
# 첫번째 컬럼 -> 이름: '제품명', 데이터: '커피','주스','밀크티'
# 두번째 컬럼 -> 이름: '가격', 데이터: 5000, 6000, 6500
# 세번째 컬럼 -> 이름: '판매량', 데이터:60, 45, 30
# index -> ['a', 'b', 'c'] 인 데이터프레임 객체 df만들기

df = pd.DataFrame({'제품명':['커피', '주스', '밀크티'],
              '가격':[5000, 6000, 6500],
              '판매량':[60, 45, 30]},
             index=['a', 'c', 'c'])

# %%
# df 확인

df
# Out:
#    제품명    가격  판매량
# a   커피  5000   60
# c   주스  6000   45
# c  밀크티  6500   30

# %%
# df를 ./data/음료판매기록.csv 파일로 저장

df.to_csv('/content/drive/MyDrive/데이터분석특강/Day_2/data/음료판매기록.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ./data/음료판매기록.csv파일 읽어 데이터프레임 객체를 df1에대입

pd.read_csv('/content/drive/MyDrive/데이터분석특강/Day_2/data/음료판매기록.csv', index_col = 0)
# Out:
#    제품명    가격  판매량
# a   커피  5000   60
# c   주스  6000   45
# c  밀크티  6500   30

# %%
# df1 확인하기

df1
# Out:
#    제품명    가격  판매량
# a   커피  5000   60
# c   주스  6000   45
# c  밀크티  6500   30

# %%
# df1의 타입 확인하기

type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
# header = 0, index_col=0 , sep=',' 옵션주고 읽어오기

pd.read_csv('/content/drive/MyDrive/데이터분석특강/Day_2/data/음료판매기록.csv', header = 0, index_col=0 , sep=',' )
# Out:
#    제품명    가격  판매량
# a   커피  5000   60
# c   주스  6000   45
# c  밀크티  6500   30

# %%
# df1 확인하기

sr1 =
# Out:
#    제품명    가격  판매량
# a   커피  5000   60
# b   주스  6000   45
# c  밀크티  6500   30

# %% [markdown]
# # 2 데이터 살펴보기

# %% [markdown]
# ## 2.1 데이터 내용 미리보기
# - 앞부분 미리보기 : DataFrame객체.**`head(n) => 기본 5개`**
# - 뒷부분 미리보기 : DataFrame객체.**`tail(n) => 기본 5개`**
# - 샘플 읽기 : DataFrame객체.**`sample(n) => 기본 1개`**

# %% [markdown]
# * UCI Machine Learning 저장소에서 제공하는 자동차연비(auto mpg) 데이터셋을 사용한다.

# %% [markdown]
# ![auto_mpg.png](data:image/png;base64,...)

# %%
# 판다스 라이브러리 임포트

import pandas as pd

# %%
# ./data/auto-mpg.csv파일을 heaer=None옵션을 설정하고 읽어온다.
# 파일로부터 읽은 내용을 변수 df에 대입한다.

df = pd.read_csv('/content/drive/MyDrive/데이터 분석 특강/ data/auto-mpg.csv',header=None)

# %%
# df 확인

df
# Out:
#         0  1      2      3       4     5   6  7                          8
# 0    18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1    15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2    18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3    16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4    17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino
# ..    ... ..    ...    ...     ...   ...  .. ..                        ...
# 393  27.0  4  140.0  86.00  2790.0  15.6  82  1            ford mustang gl
# 394  44.0  4   97.0  52.00  2130.0  24.6  82  2                  vw pickup
# 395  32.0  4  135.0  84.00  2295.0  11.6  82  1              dodge rampage
# 396  28.0  4  120.0  79.00  2625.0  18.6  82  1                ford ranger
# 397  31.0  4  119.0  82.00  2720.0  19.4  82  1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# df의 타입확인

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 데이터프레임의 컬럼명을 '
# mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'name'으로 설정한다.

df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'name']

# %%
# df 확인

df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# 데이터프레임 df의 앞 5개의 데이터를 확인한다.

df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# 데이터프레임 df의 마지막 3개의 데이터를 확인한다.

df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin             name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
# 데이터프레임 df의 샘플 데이터를 확인한다.

df.sample(2)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 74   13.0          8         302.0      140.0  4294.0          16.0
# 355  33.7          4         107.0      75.00  2210.0          14.4
#
#      model year  origin                   name
# 74           72       1  ford gran torino (sw)
# 355          81       3          honda prelude

# %% [markdown]
# ## 2.2 데이터 요약 정보 확인하기

# %% [markdown]
# - DataFrame의 크기(행, 열)확인: DataFrame객체.**`shape`**

# %%
# 데이터프레임 df의 행,열 정보를 확인한다.

df.shape
# Out:
# (398, 9)

# %% [markdown]
# - DataFrame의 기본 정보 출력: DataFrame객체.**`info()`**

# %%
# df의 기본요약 정보 출력

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# - DataFrame 각 열의 자료형 확인: DataFrame객체.**`dtypes`**

# %%
# df 각 열의 데이터타입 확인

df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight          float64
# acceleration    float64
# model year        int64
# origin            int64
# name             object
# dtype: object

# %%
# 'mpg'열의 데이터타입을 확인한다.

df['mpg'].dtypes
# Out:
# dtype('float64')

# %%
# 데이터프레임 df(수치데이터컬럼)의 기술통계 정보를 요약한다.

df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# 데이터프레임 df의 문자열 데이터 컬럼들의 기술 통계 정보를 요약한다. include='object'

df.describe(include='object')
# Out:
#        horsepower        name
# count         398         398
# unique         94         305
# top         150.0  ford pinto
# freq           22           6

# %%
# 데이터프레임 df의 모든 컬럼의 기술통계 정보를 요약한다.

df.describe(include='all')
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN      150.0          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model year      origin        name
# count     398.000000  398.000000  398.000000         398
# unique           NaN         NaN         NaN         305
# top              NaN         NaN         NaN  ford pinto
# freq             NaN         NaN         NaN           6
# mean       15.568090   76.010050    1.572864         NaN
# std         2.757689    3.697627    0.802055         NaN
# min         8.000000   70.000000    1.000000         NaN
# 25%        13.825000   73.000000    1.000000         NaN
# 50%        15.500000   76.000000    1.000000         NaN
# 75%        17.175000   79.000000    2.000000         NaN
# max        24.800000   82.000000    3.000000         NaN

# %% [markdown]
# # 3 판다스 내장 그래프 도구를 이용한 시각화
#
# 데이터를 그래프로 표현하는 것은 매우 효과적인 정보 전달 방식임
# 그래프를 이용한 시각화 방법은 데이터의 분포와 패턴을 파악하는 도움이 됨
#
#
# * 판다스는 Matplotlib 라이브러리의 기능을 일부 내장하고 있어서, 별도로 임포트하지 않고도 간단한 그래프를 손쉽게 그릴 수 있다.
# * **`시리즈 또는 데이터프레임 객체에 plot() 메소드를 적용하여 그래프를 그린다.`**
# * kind 옵션으로 그래프의 종류를 선태할 수 있다.

# %% [markdown]
# ## 3.1 선 그래프
# 데이터프레임(시리즈)객체**`.plot()`**
#
# 데이터프레임(또는 시리즈) 객체에 plot() 메소드를 적용할 때, 다른 옵션을 추가하지 않으면 가장 기본적인 선 그래프를 그린다.
#
# 데이터프레임에 plot() 메소드를 전달하면 행 인덱스를 x축에, 데이터를 y축에 적용한다.

# %%
# 판다스 라이브러리 임포트

import pandas as pd

# %%
# [1,2,3] 을 이용해 시리즈 sr1 만들기

sr1 = pd.Series(data=[1,2,3])
sr1
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# 시리즈객체 sr1의 plot()메소드를 이용해 선그래프 그리기
# x축은 시리즈의 인덱스가, y축은 시리즈의 데이터가 설정됨을 확인한다.

sr1.plot()
# Out:
# <Axes: >

# %%
# 시리즈 sr1의 인덱스를 [10, 20, 30]으로 바꾸기

sr1.index = [10, 20, 30]
sr1
# Out:
# 10    1
# 20    2
# 30    3
# dtype: int64

# %%
# sr1의 plot() 메소드로 선그래프 다시 그려보기
# x축은 시리즈의 인덱스가 y축은 시리즈의 데이터가 설정됨을 확인한다.

sr1.plot()
# Out:
# <Axes: >

# %%
# matplotlib.pyplot 임포트

import matplotlib.pyplot as plt

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# 위에 내용을 실행하고 런타임을 다시 시작해줘야 함
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (9,612 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 120874 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
from numpy import unicode_
# 한글폰드 오류해결
               # 폰트를 NanumBarunGothic으로 설정
plt.rc('font', family='NanumBarunGothic')
# x,y축에 -부호 오류 해결
plt.rc('axes', unicode_minus = False)

# %%
# 시리즈 객체 sr1의 plot()메소드로 선그래프그리고 옵션설정하기
# title='그래프제목'
# color='red' (선색)
# figsize=(10, 5) (그래프가로세로크기)
# xticks=[10, 20, 30] (x축 눈금표시)

sr1.plot(color='red', figsize=(10,5), xticks=[10,20,30], title='그래프제목')
# Out:
# <Axes: title={'center': '그래프제목'}>

# %%
# {'a':[1, 2, 3, 4], 'b':[1, 4, 9, 16], 'c':[1, 8, 27, 64]}을 이용하여 데이터프레임 df1을 생성한다.

df1 = pd.DataFrame({'a':[1,2,3,4],
              'b':[1,4,9,16],
              'c':[1,8,27,64]})
df1
# Out:
#    a   b   c
# 0  1   1   1
# 1  2   4   8
# 2  3   9  27
# 3  4  16  64

# %%
# 데이터프레임 객체 df1의 plot()메소드를 이용하여 선그래프를 그린다.
# x축은 데이터프레임의 인덱스가 y축은 각 컬럼의 데이터가 설정되었음을 확인한다.
# 컬럼의 수만큼 선이 그려진다.

df1.plot()
# Out:
# <Axes: >

# %%
# df1의 인덱스를  [10, 20, 30, 40]로 변경한다.

df1.index = [10,20,30,40]
df1
# Out:
#     a   b   c
# 10  1   1   1
# 20  2   4   8
# 30  3   9  27
# 40  4  16  64

# %%
# 데이터프레임 객체 df1의 plot()메소드를 이용하여 선그래프를 그린다.
# x축은 데이터프레임의 인덱스가 y축은 각 컬럼의 데이터가 설정되었음을 확인한다.
# 컬럼의 수만큼 선이 그려진다.

df1.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## 3.2 막대 그래프
# 데이터프레임(시리즈)객체.<b>`plot(kind='bar')`</b>
# 데이터프레임(시리즈)객체.<b>`plot.bar()`</b>
# 데이터프레임(시리즈)객체.<b>`plot(kind='barh')`</b>
# 데이터프레임(시리즈)객체.<b>`plot.barh()`</b>

# %%
# 시리즈 객체 sr1확인

sr1
# Out:
# 10    1
# 20    2
# 30    3
# dtype: int64

# %%
# 데이터프레임 객체 df1 확인

df1
# Out:
#     a   b   c
# 10  1   1   1
# 20  2   4   8
# 30  3   9  27
# 40  4  16  64

# %%
# 시리즈객체 sr1의 plot()메소드를 이용하여 막대 그래프 그리기
# x축은 시리즈의 인덱스가, y축은 시리즈의 데이터가 설정됨을 확인한다.

sr1.plot(kind='bar')
# Out:
# <Axes: >

# %%
# sr1.plot.bar()
# rot=각도

sr1.plot.bar(rot=0)
# Out:
# <Axes: >

# %%
# 데이터프레임객체 df1의 plot() 메소드를 이용하여 막대그래프 그리기
# x축: 데이터프레임의 인덱스, y축: 데이터프레임의 데이터 가 설정됨을 확인한다.
# 데이터프레임의 컬럼 수 만큼 막대가 그려진다.

df1.plot.bar(rot=0)
# Out:
# <Axes: >

# %% [markdown]
# ## 3.3 히스토그램
# 데이터프레임(시리즈)객체.<b>`plot(kind='hist')`</b>
# 데이터프레임(시리즈)객체.<b>`plot.hist()`</b>
# 데이터프레임(시리즈)객체.<b>`hist(grid=False)`</b>
# * x축은 데이터가 일정한 간격을 갖는 여러 구간으로 나뉘고, y축은 데이터가 x축에서 나눈 구간에 속하는 컬럼의 빈도수를 나타낸다.

# %%
# data=[1, 1, 2, 3, 2, 4], index=[10, 20, 30, 40, 50, 60]를 갖는 시리즈 객체 sr2를 생성한다.

sr2 = pd.Series(data=[1,1,2,3,2,4], index=[10,20,30,40,50,60])
sr2
# Out:
# 10    1
# 20    1
# 30    2
# 40    3
# 50    2
# 60    4
# dtype: int64

# %%
# 시리즈객체 sr2의 plot()메소드로 히스토그램을 그린다.
# x축: sr2의 데이터를 기본적으로 10개의 구간(bins=10)으로 나누어 표시한다.
# y축: sr2의 데이터의 개수를 표시한다.

sr2.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#  x축의 구간을 20개로 설정하고 히스토그램을 그린다.(bins=20)

sr2.plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# {'a':[1, 2, 1, 3], 'b':[2, 3, 3, 1], 'c':[1, 3, 4, 3]} 값을 가지는 데이터프레임객체 df2를 생성한다.

df2 = pd.DataFrame({'a':[1, 2, 1, 3], 'b':[2, 3, 3, 1], 'c':[1, 3, 4, 3]})
df2
# Out:
#    a  b  c
# 0  1  2  1
# 1  2  3  3
# 2  1  3  4
# 3  3  1  3

# %%
# 데이터프레임객체 df2의 plot()메소들 이용해 히스토그램을 그린다.
# x축에는 데이터프레임의 모든 데이터를 기본적으로 10개의 구간으로(bins=10) 나누어 표시한다.
# y축에는 데이터프레임의 모든 데이터의 개수를 나타낸다.
# 데이터프레임의 모든 컬럼에 대한 막대들이 색깔로구분되어(범례(legend)) 표시된다.
# 같은 위치의 데이터는 겹쳐져 표현되므로 마지막 컬럼의 데이터가 덮어쓴 형태로 표시된다.

df2.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# df2.hist()

df2.hist()
# Out:
# array([[<Axes: title={'center': 'a'}>, <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'c'}>, <Axes: >]], dtype=object)

# %%
# df2['a']열의  plot() 메소드를 이용하여 히스토그램을 그린다.

df2['a'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## 3.4 산점도
# 데이터프레임객체.<b>`plot(kind='scatter', x='컬럼명', y='컬럼명')`</b>
# # 데이터프레임객체.<b>`plot.scatter(x='컬럼명', y='컬럼명')`
# * 데이터중 2개의 변수 간의 관계를 표현한다.

# %%
# 데이터프레임 객체  df1을 확인한다.

df1
# Out:
#     a   b   c
# 10  1   1   1
# 20  2   4   8
# 30  3   9  27
# 40  4  16  64

# %%
# 데이터프레임 객체  df1의 plot()메소드를 이용하여 산점도 그래프를 그린다.
# df1의 'a'열과 'b'열의 상관관계를 확인한다.x='a'열, y='b'열

df1.plot(kind='scatter', x='a', y='b')
df1.plot.scatter(x='a', y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# ## 3.5 박스 플롯
# 데이터프레임(시리즈)객체.<b>`plot(kind='box')`</b>
# 데이터프레임(시리즈)객체.<b>`plot.box()`</b>
# * 박스플롯은 특정 변수의 데이터 분포와 분산 정도에 대한 정보를 제공한다.

# %%
# [1, 1, 2, 3, 2, 4, 11], name='series1' 값을 가지는 시리즈객체 sr3를 생성한다.

sr3 = pd.Series([1, 1, 2, 3, 2, 4, 11], name='series1')
sr3
# Out:
# 0     1
# 1     1
# 2     2
# 3     3
# 4     2
# 5     4
# 6    11
# Name: series1, dtype: int64

# %%
# 시리즈객체인 sr3의 plot()메소들 이용해 박스플롯을 그린다.
# sr3의 데이터의 분포를 보여줌을 확인한다.(min, 25%, median, 75%, max)
# 데이터중 이상치(outlier)가 있을 경우 표시한다.

sr3.plot(kind='box')
# Out:
# <Axes: >

# %%
# df2를 확인한다.

df2
# Out:
#    a  b  c
# 0  1  2  1
# 1  2  3  3
# 2  1  3  4
# 3  3  1  3

# %%
# 데이터프레임객체 df2의 plot()메소드를 이용하여 박스플롯을 그린다.
# 데이터프레임의 모든 열의 데이터분포흘 표시함을 확인한다.

df2.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# # 4 판다스를 이용한 시각화 예제

# %% [markdown]
# ## 4.1선그래프
# * 남북한의 발전량 데이터셋을 이용하여 선그래프를 그려본다.

# %%
# 판다스, matplotlib.pyplot 불러오기

import pandas as pd
import matplotlib.pyplot as plt

# %%
# 한글폰드 오류해결
plt.rc('font', family='NanumBarunGothic') # 폰트를 NanumBarunGothic으로 설정

# x,y축에 -부호 오류 해결
plt.rc('axes', unicode_minus=False)

# %%
# './data/남북한발전전력량.xlsx' 파일 불러와 df에 대입하기

df = pd.read_excel('/content/drive/MyDrive/데이터 분석 특강/ data/남북한발전전력량.xlsx')

# %%
# df의 행,열 살펴보기 (shape)

df.shape
# Out:
# (9, 29)

# %%
# 데이터프레임의 앞의 5개 데이터 확인해보기

df.head()
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# 2  2658  2802  3196  3343  3430  3581  3427  3402  3523
# 3  1510  1478  1486  1547  1503  1388  1564  1648  1620
# 4     -     -     -     -    86   118   151   173   195
#
# [5 rows x 29 columns]

# %%
# 데이터프레임의 마지막 5개 데이터 확인해보기

df.tail()
# Out:
#   전력량 (억㎾h) 발전 전력별 1990 1991 1992 1993 1994 1995 1996 1997  ... 2007 2008  \
# 4       NaN    신재생    -    -    -    -    -    -    -    -  ...    -    -
# 5        북한     합계  277  263  247  221  231  230  213  193  ...  236  255
# 6       NaN     수력  156  150  142  133  138  142  125  107  ...  133  141
# 7       NaN     화력  121  113  105   88   93   88   88   86  ...  103  114
# 8       NaN    원자력    -    -    -    -    -    -    -    -  ...    -    -
#
#   2009 2010 2011 2012 2013 2014 2015 2016
# 4    -    -    -   86  118  151  173  195
# 5  235  237  211  215  221  216  190  239
# 6  125  134  132  135  139  130  100  128
# 7  110  103   79   80   82   86   90  111
# 8    -    -    -    -    -    -    -    -
#
# [5 rows x 29 columns]

# %%
# df의 샘플 5개 보기

df.sample(5)
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 8     -     -     -     -     -     -     -     -     -
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 2  2658  2802  3196  3343  3430  3581  3427  3402  3523
# 1    56    56    65    78    77    84    78    58    66
# 5   255   235   237   211   215   221   216   190   239
#
# [5 rows x 29 columns]

# %%
# 데이터프레임 인덱스 확인하기

df.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
# 데이터프레임 컬럼 확인

df.columns
# Out:
# Index(['전력량 (억㎾h)', '발전 전력별', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016'],
#       dtype='object')

# %%
# 데이터프레임 요약정보 확인

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 29 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   전력량 (억㎾h)  2 non-null      object
#  1   발전 전력별     9 non-null      object
#  2   1990       9 non-null      object
#  3   1991       9 non-null      object
#  4   1992       9 non-null      object
#  5   1993       9 non-null      object
#  6   1994       9 non-null      object
#  7   1995       9 non-null      object
#  8   1996       9 non-null      object
#  9   1997       9 non-null      object
#  10  1998       9 non-null      object
#  11  1999       9 non-null      object
#  12  2000       9 non-null      object
#  13  2001       9 non-null      object
#  14  2002       9 non-null      object
#  15  2003       9 non-null      object
#  16  2004       9 non-null      object
#  17  2005       9 non-null      object
#  18  2006       9 non-null      object
#  19  2007       9 non-null      object
#  20  2008       9 non-null      object
#  21  2009       9 non-null      object
#  22  2010       9 non-null      object
#  23  2011       9 non-null      object
#  24  2012       9 non-null      object
#  25  2013       9 non-null      object
#  26  2014       9 non-null      object
#  27  2015       9 non-null      object
#  28  2016       9 non-null      object
# dtypes: object(29)
# memory usage: 2.2+ KB

# %%
df
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# 2  2658  2802  3196  3343  3430  3581  3427  3402  3523
# 3  1510  1478  1486  1547  1503  1388  1564  1648  1620
# 4     -     -     -     -    86   118   151   173   195
# 5   255   235   237   211   215   221   216   190   239
# 6   141   125   134   132   135   139   130   100   128
# 7   114   110   103    79    80    82    86    90   111
# 8     -     -     -     -     -     -     -     -     -
#
# [9 rows x 29 columns]

# %%
# 남한, 북한  발전량 합게 데이터만 추출해서  df_ns 에 대입

df_ns = df.iloc[[0,5], 2:]
df_ns
# Out:
#    1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  ...  2007  \
# 0  1077  1186  1310  1444  1650  1847  2055  2244  2153  2393  ...  4031
# 5   277   263   247   221   231   230   213   193   170   186  ...   236
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 5   255   235   237   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
# df_ns의 행인덱스를 'South', 'North'로 변경

df_ns.index = ['South', 'North']
df_ns
# Out:
#        1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  ...  2007  \
# South  1077  1186  1310  1444  1650  1847  2055  2244  2153  2393  ...  4031
# North   277   263   247   221   231   230   213   193   170   186  ...   236
#
#        2008  2009  2010  2011  2012  2013  2014  2015  2016
# South  4224  4336  4747  4969  5096  5171  5220  5281  5404
# North   255   235   237   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
# df_ns의 plot메소를 이용하여 선그래프 그리기
# 인덱스가 x축에 데이터는 y축에 할당됨

df_ns.plot(figsize=(10,6))
# Out:
# <Axes: >

# %% [markdown]
# * 시간의 흐름에 따른 연도별 발전량 변화 추이를 보기 위해서 연도값을 x축에 표시하는 것이 적절하다.
# 연도 값을 x축으로 바꾸기 위해서 열 이름을 구성하고 있는 연도 값이 행 인덱스에 위치하도록 행렬을 전치한다.

# %%
# df_ns의 행과 열을 전치하고 tdf_ns에 대입한다.

tdf_ns = df_ns.transpose()
tdf_ns
# Out:
#      South North
# 1990  1077   277
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# 1996  2055   213
# 1997  2244   193
# 1998  2153   170
# 1999  2393   186
# 2000  2664   194
# 2001  2852   202
# 2002  3065   190
# 2003  3225   196
# 2004  3421   206
# 2005  3646   215
# 2006  3812   225
# 2007  4031   236
# 2008  4224   255
# 2009  4336   235
# 2010  4747   237
# 2011  4969   211
# 2012  5096   215
# 2013  5171   221
# 2014  5220   216
# 2015  5281   190
# 2016  5404   239

# %%
# tdf_ns의 인덱스 확인

tdf_ns.index
# Out:
# Index(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')

# %%
# tdf_ns의 컬럼명 확인

tdf_ns.columns
# Out:
# Index(['South', 'North'], dtype='object')

# %%
# tdf_ns의 plot메소를 이용하여 선그래프 그리기
# 인덱스가 x축에 데이터는 y축에 할당됨

tdf_ns.plot()
# Out:
# <Axes: >

# %%
# 남한의정보만 그래프로 그리기
# tdf_ns['South'](시리즈) 의 plot메소드를 이용하여 선그래프 그리기
# 인덱스가 x축에 데이터는 y축에 할당됨

tdf_ns['South'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## 4.2 막대 그래프
# 데이터프레임(시리즈)객체.<b>`plot(kind='bar')`</b>
#
# * 남북한의 발전량 데이터셋을 이용하여 막대 그래프를 그린다.

# %%
df_ns
# Out:
#        1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  ...  2007  \
# South  1077  1186  1310  1444  1650  1847  2055  2244  2153  2393  ...  4031
# North   277   263   247   221   231   230   213   193   170   186  ...   236
#
#        2008  2009  2010  2011  2012  2013  2014  2015  2016
# South  4224  4336  4747  4969  5096  5171  5220  5281  5404
# North   255   235   237   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
# df_ns의 plot메소를 이용하여 막대 그래프 그리기
# 인덱스가 x축에 데이터는 y축에 할당됨

df_ns.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# * 결과 그래프를 보면 남한의 발전량을 계속 증가했지만, 북한의 경우 지난 20년 동안 큰 변화가 없다

# %%
tdf_ns
# Out:
#      South North
# 1990  1077   277
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# 1996  2055   213
# 1997  2244   193
# 1998  2153   170
# 1999  2393   186
# 2000  2664   194
# 2001  2852   202
# 2002  3065   190
# 2003  3225   196
# 2004  3421   206
# 2005  3646   215
# 2006  3812   225
# 2007  4031   236
# 2008  4224   255
# 2009  4336   235
# 2010  4747   237
# 2011  4969   211
# 2012  5096   215
# 2013  5171   221
# 2014  5220   216
# 2015  5281   190
# 2016  5404   239

# %%
tdf_ns.plot.bar()
# Out:
# <Axes: >

# %%
# tdf_ns의 plot메소를 이용하여 막대 그래프 그리기
# 인덱스가 x축에 데이터는 y축에 할당됨

tdf_ns.plot.barh()
# Out:
# <Axes: >

# %%
# 남한의정보만 그래프로 그리기
# tdf_ns['South'](시리즈) 의 plot메소드를 이용하여 막대 그래프 그리기
# 인덱스가 x축에 데이터는 y축에 할당됨

tdf_ns['South'].plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ## 4.3 히스토그램
# 데이터프레임(시리즈)객체.<b>`plot(kind='hist')`</b>
# * x축은 데이터가 일정한 간격을 갖는 여러 구간으로 나뉘고, y축은 데이터가 x축에서 나눈 구간에 속하는 컬럼의 빈도수를 나타낸다.

# %%
# df_ns 데이터프레임 확인

df_ns
# Out:
#        1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  ...  2007  \
# South  1077  1186  1310  1444  1650  1847  2055  2244  2153  2393  ...  4031
# North   277   263   247   221   231   230   213   193   170   186  ...   236
#
#        2008  2009  2010  2011  2012  2013  2014  2015  2016
# South  4224  4336  4747  4969  5096  5171  5220  5281  5404
# North   255   235   237   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
a = df_ns.astype('float')

# %%
# df_ns.plot으로 히스토그램 작성

a.plot(kind='hist')

# 결과 그래프의 의미가 정확하지 않음
# Out:
# <Axes: ylabel='Frequency'>

# %%
# tdf_ns 데이터프레임 확인

tdf_ns
# Out:
#      South North
# 1990  1077   277
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# 1996  2055   213
# 1997  2244   193
# 1998  2153   170
# 1999  2393   186
# 2000  2664   194
# 2001  2852   202
# 2002  3065   190
# 2003  3225   196
# 2004  3421   206
# 2005  3646   215
# 2006  3812   225
# 2007  4031   236
# 2008  4224   255
# 2009  4336   235
# 2010  4747   237
# 2011  4969   211
# 2012  5096   215
# 2013  5171   221
# 2014  5220   216
# 2015  5281   190
# 2016  5404   239

# %%
b = tdf_ns.astype('float')

# %%
# tdf_ns에 plot()메소들 이용하여 히스토그램 작성

b.plot(kind='hist', grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# * 위 결과를 보면 x축은 발전량을 일정한 간격을 갖는 여러 구간으로
# 나눈 것이고, y축은 연간 발전량이 x축에서 나눈 발전량 구간에 속하는 연도의 수를 빈도로 나타낸 것이다.
# 북한의 경우 지난 26년 동안 줄곧 800 미만의 발전량을 기록한 것을 데이터로 확인할 수 있다.

# %%
# 남한의정보만 그래프로 그리기

# %% [markdown]
# ## 4.4 산점도
# 데이터프레임객체.<b>`plot(kind='scatter', x='컬럼명', y='컬럼명')`</br>
# * 데이터중 2개의 변수 간의 관계를 표현한다.

# %% [markdown]
# * UCI 자동차 연비 데이터셋을 이용하여 두 변수의 관계를 나타내는 산점도를 그린다.
# 차량의 무게와 연비 사이의 관계를 산점도를 이용해 표현한다.

# %%
# auto_mpg.csv 파일을 로드한다.
# 단, auto_mpg.csv파일의 첫번째행은 헤더가 아니다.

df = pd.read_csv('/content/drive/MyDrive/데이터 분석 특강/ data/auto-mpg.csv')

# %%
# df의 행렬 살펴보기 (shape)
df.shape
# Out:
# (397, 9)

# %%
# df의 앞쪽 데이터 확인

df.head()
# Out:
#    18.0  8  307.0  130.0   3504.  12.0  70  1 chevrolet chevelle malibu
# 0  15.0  8  350.0  165.0  3693.0  11.5  70  1         buick skylark 320
# 1  18.0  8  318.0  150.0  3436.0  11.0  70  1        plymouth satellite
# 2  16.0  8  304.0  150.0  3433.0  12.0  70  1             amc rebel sst
# 3  17.0  8  302.0  140.0  3449.0  10.5  70  1               ford torino
# 4  15.0  8  429.0  198.0  4341.0  10.0  70  1          ford galaxie 500

# %%
# df의 뒤쪽 데이터 확인

df.tail()
# Out:
#      18.0  8  307.0  130.0   3504.  12.0  70  1 chevrolet chevelle malibu
# 392  27.0  4  140.0  86.00  2790.0  15.6  82  1           ford mustang gl
# 393  44.0  4   97.0  52.00  2130.0  24.6  82  2                 vw pickup
# 394  32.0  4  135.0  84.00  2295.0  11.6  82  1             dodge rampage
# 395  28.0  4  120.0  79.00  2625.0  18.6  82  1               ford ranger
# 396  31.0  4  119.0  82.00  2720.0  19.4  82  1                chevy s-10

# %%
# df의 요약 정보확인

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   18.0                       397 non-null    float64
#  1   8                          397 non-null    int64
#  2   307.0                      397 non-null    float64
#  3   130.0                      397 non-null    object
#  4   3504.                      397 non-null    float64
#  5   12.0                       397 non-null    float64
#  6   70                         397 non-null    int64
#  7   1                          397 non-null    int64
#  8   chevrolet chevelle malibu  397 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.0+ KB

# %%
# df의 컬럼명 확인

df.columns
# Out:
# Index(['18.0', '8', '307.0', '130.0', '3504.', '12.0', '70', '1',
#        'chevrolet chevelle malibu'],
#       dtype='object')

# %%
# df의 인덱스 확인

df.index
# Out:
# RangeIndex(start=0, stop=397, step=1)

# %%
# df의 열이름을 ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'name']로 변경한다.

df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'name']
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    15.0          8         350.0      165.0  3693.0          11.5
# 1    18.0          8         318.0      150.0  3436.0          11.0
# 2    16.0          8         304.0      150.0  3433.0          12.0
# 3    17.0          8         302.0      140.0  3449.0          10.5
# 4    15.0          8         429.0      198.0  4341.0          10.0
# ..    ...        ...           ...        ...     ...           ...
# 392  27.0          4         140.0      86.00  2790.0          15.6
# 393  44.0          4          97.0      52.00  2130.0          24.6
# 394  32.0          4         135.0      84.00  2295.0          11.6
# 395  28.0          4         120.0      79.00  2625.0          18.6
# 396  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin                name
# 0            70       1   buick skylark 320
# 1            70       1  plymouth satellite
# 2            70       1       amc rebel sst
# 3            70       1         ford torino
# 4            70       1    ford galaxie 500
# ..          ...     ...                 ...
# 392          82       1     ford mustang gl
# 393          82       2           vw pickup
# 394          82       1       dodge rampage
# 395          82       1         ford ranger
# 396          82       1          chevy s-10
#
# [397 rows x 9 columns]

# %%
# 'weight'와 'mpg'와의 산점도 그래프를 작성한다.
# x측: weight, y축:mpg

df.plot.scatter(x='weight', y='mpg')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %% [markdown]
# * 결과 그래프를 보면 차량의 무게(weight)가 클수록 연비(mpg)는 전반적으로 낮아지는 경향을 보인다.
# 차량의 무게와 연비는 역(-)의 상관관계를 갖는다고 해석할 수 있다.

# %% [markdown]
# ## 4.5 박스 플롯
# 데이터프레임(시리즈)객체.<b>`plot(kind='box')`</b>
# * 박스플롯은 특정 변수의 데이터 분포와 분산 정도에 대한 정보를 제공한다.

# %% [markdown]
# * UCI 자동차 연비 데이터 셋을 이용한다.
# 자동차 연비(mpg)와 실린더개수(cylinders)의 데이터 분포에 대해 박스플롯으로 확인한다.

# %%
# df중 mpg와 cylinders를 선택하여 박스플롯을 그린다.

df[['mpg', 'cylinders']].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# * 위 결과를 보면 연비(mpg) 데이터는 10~45 범위에 넓게 분포되어 있따. 또한 'o'표시의 이상값(outlier)도 확인된다.
# 반면, 실린더개수(cylinders)는 10미만의 좁은 범위에 몰려 있다.

# %%
# df 전체 데이터에 대하여 박스플롯을 그린다.

df.plot.box()
# Out:
# <Axes: >
